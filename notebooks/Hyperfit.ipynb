# %% [markdown]
# # Hyperelastic Model Fitting

# %%
# %load_ext autoreload
# %autoreload 2
from numpy import *
import numpy as np
from bokeh.plotting import *
from pandas import read_excel
from matmodlab2.fitting.hyperopt import *
output_notebook()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c7dcabc1-076c-44a7-ad68-311dec9fe45c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Experimental Data

# %%
# uniaxial data
udf = read_excel('Treloar_hyperelastic_data.xlsx', sheetname='Uniaxial')
ud = udf.as_matrix(columns=('Engineering Strain', 'Engineering Stress (MPa)'))

# Biaxial data
bdf = read_excel('Treloar_hyperelastic_data.xlsx', sheetname='Biaxial')
bd = bdf.as_matrix(columns=('Engineering Strain', 'Engineering Stress (MPa)'))

# Pure shear data
sdf = read_excel('Treloar_hyperelastic_data.xlsx', sheetname='Pure Shear')
sd = sdf.as_matrix(columns=('Engineering Strain', 'Engineering Stress (MPa)'))

# %% [markdown]
# ## Uniaxial Data
#
# Find the optimal fit to the uniaxial stress data with a hyperelastic polynomial model.  The symbolic constant `UNIAXIAL_DATA` instructs `hyperopt` to interpret the input data as coming from a uniaxial stress experiment.

# %%
uf = hyperopt(UNIAXIAL_DATA, ud[:,0], ud[:,1])
print(uf.summary())
# Out:
#             Data type: Uniaxial
# Number of data points: 23
#      Polynomial order: 5
#         I2 dependence: True
#            Parameters: C10=-395859933.045, C01=132250968.904, C20=-134170727.507, C11=104493666.738, C02=-33928679.075, C30=11734697.899, C21=-11610156.849, C12=-24806492.415, C03=17653757.438, C40=-4337674.748, C31=-4054457.364, C22=-1034831.948, C13=3875358.131, C04=9768482.730, C50=-270732.550, C41=901202.455, C32=-1893102.941, C23=989459.036, C14=4834111.469, C05=-3146197.619
#                 Error: 0.019832218829249654

# %% [markdown]
# At this point, the optimal parameters have been determined and are accessible with the `popt` attribute:

# %%
uf.popt
# Out:
# array([ -3.95859933e+08,   1.32250969e+08,  -1.34170728e+08,
#          1.04493667e+08,  -3.39286791e+07,   1.17346979e+07,
#         -1.16101568e+07,  -2.48064924e+07,   1.76537574e+07,
#         -4.33767475e+06,  -4.05445736e+06,  -1.03483195e+06,
#          3.87535813e+06,   9.76848273e+06,  -2.70732550e+05,
#          9.01202455e+05,  -1.89310294e+06,   9.89459036e+05,
#          4.83411147e+06,  -3.14619762e+06])

# %% [markdown]
# The optimal parameters are also available as a dictionary via the `todict` method:

# %%
uf.todict()
# Out:
# {'C01': 132250968.90355907,
#  'C02': -33928679.074741118,
#  'C03': 17653757.438015793,
#  'C04': 9768482.730201792,
#  'C05': -3146197.6186751584,
#  'C10': -395859933.04529548,
#  'C11': 104493666.73756613,
#  'C12': -24806492.414594918,
#  'C13': 3875358.1313264915,
#  'C14': 4834111.4689746331,
#  'C20': -134170727.5069174,
#  'C21': -11610156.84929673,
#  'C22': -1034831.9476936288,
#  'C23': 989459.03600392921,
#  'C30': 11734697.899416655,
#  'C31': -4054457.3641825169,
#  'C32': -1893102.9406949782,
#  'C40': -4337674.7481137849,
#  'C41': 901202.45488339872,
#  'C50': -270732.54991535202}

# %% [markdown]
# The error in the fit:

# %%
uf.error
# Out:
# 0.019832218829249654

# %% [markdown]
# Plots are generated with the `bp_plot` method

# %%
show(uf.bp_plot())
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id
","type":"BoxAnnotation"},{"id":"bad7eaa4-b600-4a6a-8605-f1a0ba571294","type":"Legend"},{"id":"326784d0-c021-42b6-9361-f1492e738a6c","type":"GlyphRenderer"},{"id":"a0882b8e-0c15-49ab-ba68-fcfd88ac1e80","type":"GlyphRenderer"}],"title":{"id":"c23ffea8-a0f8-43b6-a9d4-cb2e4ddb5343","type":"Title"},"tool_events":{"id":"bff086bd-bc04-4639-951c-a538622f870b","type":"ToolEvents"},"toolbar":{"id":"a0df40e3-3d8c-480d-a72d-751a84767ef9","type":"Toolbar"},"x_range":{"id":"6d335e82-27ce-46fc-a3d0-ae8317c1b280","type":"DataRange1d"},"y_range":{"id":"7f68b439-7309-4a88-9d6b-ad85c1443acc","type":"DataRange1d"}},"id":"b829c098-d46c-47d8-aa03-7c5d6f5b1bc1","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"bff086bd-bc04-4639-951c-a538622f870b","type":"ToolEvents"},{"attributes":{"plot":{"id":"b829c098-d46c-47d8-aa03-7c5d6f5b1bc1","subtype":"Figure","type":"Plot"}},"id":"3f9cd2cd-4358-4ce9-b397-51083fe0af13","type":"WheelZoomTool"},{"attributes":{},"id":"583c21f5-cb6c-4ca3-a732-ecf3d5baf4ec","type":"BasicTicker"},{"attributes":{"plot":{"id":"b829c098-d46c-47d8-aa03-7c5d6f5b1bc1","subtype":"Figure","type":"Plot"}},"id":"cafb6ec2-4e67-4ffe-be88-d768e41f8b7b","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1 ...

# %% [markdown]
# ## Biaxial Data
#
# Biaxial data is fit in a similar manner:

# %%
bf = hyperopt(BIAXIAL_DATA, bd[:,0], bd[:,1])
print(bf.summary())
show(bf.bp_plot())
# Out:
#             Data type: Biaxial
# Number of data points: 16
#      Polynomial order: 4
#         I2 dependence: True
#            Parameters: C10=48126616.023, C01=-14323537.793, C20=597202131.473, C11=-420483882.811, C02=108970996.079, C30=416916020.562, C21=-85123697.713, C12=-35925284.204, C03=-3410748.604, C40=105722602.577, C31=9671542.604, C22=2942836.173, C13=-267685.707, C04=16785.785
#                 Error: 0.00990862004186524
#     <div class="bk-root">
#         <div class="plotdiv" id="955ae65e-e479-4326-9d92-ab59e87d6a20"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#955ae65e-e479-4326-9d92-ab59e87d6a20").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("955ae65e-e479-4326-9d92-ab59e87d6a20");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '955ae65e-e479-4326-9d92-ab59e87d6a20' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5536060c-3675-4404-a2b3-7a20f20b4ed7":{"roots":{"references":[{"attributes":{"legends":[["Biaxial Data, data",[{"id":"83cf0d6b-95f0-4290-957f-15d289037649","type":"GlyphRenderer"}]],["Biaxial Data, fit",[{"id":"0d664091-e6b2-4f18-a0ea-ad3410e4913b","type":"GlyphRenderer"}]]],"plot":{"id":"4837ae10-4683-4a0e-b6a6-5b17273e863b","subtype":"Figure","type":"Plot"}},"id":"3c19cce4-5600-4f5b-88bb-37cb428e8635","type":"Legend"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[
type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"157bd142-df8a-4f7f-af96-e3d5d2d5bf18","type":"Circle"},"selection_glyph":null},"id":"83cf0d6b-95f0-4290-957f-15d289037649","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.02,0.05464646464646465,0.0892929292929293,0.12393939393939395,0.15858585858585858,0.19323232323232323,0.22787878787878788,0.26252525252525255,0.2971717171717172,0.33181818181818185,0.3664646464646465,0.40111111111111114,0.4357575757575758,0.47040404040404044,0.5050505050505051,0.5396969696969698,0.5743434343434344,0.608989898989899,0.6436363636363637,0.6782828282828284,0.712929292929293,0.7475757575757576,0.782222222 ...

# %% [markdown]
# ## Shear Data
#
# Lastly, the shear data is fit

# %%
sf = hyperopt(SHEAR_DATA, sd[:,0], sd[:,1])
print(sf.summary())
show(sf.bp_plot())
# Out:
#             Data type: Shear
# Number of data points: 13
#      Polynomial order: 3
#         I2 dependence: True
#            Parameters: C10=-480403082.071, C01=161106124.736, C20=-278863992.929, C11=38177864.867, C02=56699970.680, C30=-29401178.157, C21=-4432.913, C12=2952118.412, C03=-752519.876
#                 Error: 0.018242925241750776
#     <div class="bk-root">
#         <div class="plotdiv" id="7bf8e7e6-6677-44a3-a988-896eca6aecc0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#7bf8e7e6-6677-44a3-a988-896eca6aecc0").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7bf8e7e6-6677-44a3-a988-896eca6aecc0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7bf8e7e6-6677-44a3-a988-896eca6aecc0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4d629fab-3851-44e6-bcb8-80c95fdec008":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"aecaee15-5676-405f-8684-dfd0d7f0acf4","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"06292f0c-e552-46eb-b7f4-a56af2792468","type":"LinearAxis"}],"left":[{"id":"64699051-a37e-4fed-a2aa-d37a8627bacb","type":"LinearAxis"}],"renderers":[{"id":"06292f0c-e552-46eb-b7f4-a56af2792468","type":"LinearAxis"},{"id":"0feca6fa-369c-4c4a-9238-c5745f6dfc05","type":"Grid"},{"id":"64699051-a37e-4fed-a2aa-d37a8627bacb","type":"LinearAxis"},{"id":"2a54e1c4-f3ca-4169-873a-5ef43783cd2d","type":"Grid"},{"id":"aecaee15-5676-405f-8684-dfd0d7f0acf4","type":"BoxAnnotation"},{"id":"7927b73d-50c3-4a0a-904d-f60cae9f735b","type":"Legend"},{"id":"0d3cd05e-0d83-4596-9bed-b46722a1bbe5","type":"GlyphRenderer"},{"id":"fb491cd6-140a-4b24-a6e2-af8204df7e4b","type":"GlyphRenderer"}],"title":{"id":"41f50729-2164-4037-a7ec-f004d48840a4","type":"Title"},"tool_events":{"id":"b422912d-eb88-44f2-b0e1-fe0214cb2121","type":"ToolEvents"},"toolbar":{"id":"f28f65d7-9b5b-4666-8f7d-98eb5eab47dc","type":"Toolbar"},"x_range":{"id":"3b1a87be-0e25-4fef-bddc-20f0f446fcd2","type":"DataRange1d"},"y_range":{"id":"642cf220-476a-4258-bbad-c7dbf5bb5c1c","type":"DataRange1d"}},"id":"e6eacb86-609b-4922-8dea-9b9b119ddc52","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c79713b5-1e3e-42e5-bc4e-b453daf141a1","type":"ResizeTool"},{"id":"2e45d29f-30fb-44d5-b144-6ae744aff3c1","type":"PanTool"},{"id":"04d9208a-db16-4fe9-b864-1e6abe6eb9e2","type":"WheelZoomTool"},{"id":"ff268038-5aa2-42ae-8d9a-9e69097de7e5","type":"BoxZoomTool"},{"id":"4ddf356b-b8d4-476d-bdad-61425905e098","type":"ResetTool"},{"id":"f9ec9c8c-4b9a-4c30-92ce-d27205ce8bc2","type":"SaveTool"}]},"id":"f28f65d7-9b5b-4666-8f7d-98eb5eab47dc","type":"Toolbar"},{"attributes":{},"id":"b422912d-eb88-44f2-b0e1-fe0214cb2121","type":"ToolEvents"},{"attributes":{"overlay":{"id":"aecaee15-5676-405f-8684-dfd0d7f0acf4","type":"BoxAnnotation"},"plot":{"id":"e6eacb86-609b-4922-8dea-9b9b119ddc52","subtype":"Figure","type":"Plot"}},"id":"ff268038-5aa2-42ae-8d9a-9e69097de7e5","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d2ddadeb-bef0-40dc-8349-29455040ba28","type":"Line"},{"attributes":{"plot":{"id":"e6eacb86-609b-4922-8dea-9b9b119ddc52","subtype":"Figure","type":"Plot"},"ticker":{"id":"d61b2540-eb22-438c-a37f-9c6a2a381e45","type":"BasicTicker"}},"id":"0feca6fa-369c-4c4a-9238-c5745f6dfc05","type":"Grid"},{"attributes":{},"id":"c4e7b1d7-9856-44bb-85e3-0fe01c72f1be","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"aa5acc7c-7083-4fa0-bcea-61e91a44c6fd","type":"Circle"},{"attributes":{"legends":[["Shear Data, data",[{"id":"0d3cd05e-0d83-4596-9bed-b46722a1bbe5","type":"GlyphRenderer"}]],["Shear Data, fit",[{"id":"fb491cd6-140a-4b24-a6e2-af8204df7e4b","type":"GlyphRenderer"}]]],"plot":{"id":"e6eacb86-609b-4922-8dea-9b9b119ddc52","subtype":"Figure","type":"Plot"}},"id":"7927b73d-50c3-4a0a-904d-f60cae9f735b","type":"Legend"},{"attributes":{"plot":{"id":"e6eacb86-609b-4922-8dea-9b9b119ddc52","subtype":"Figure","type":"Plot"}},"id":"c79713b5-1e3e-42e5-bc4e-b453daf141a1","type":"ResizeTool"},{"attributes":{},"id":"373eccf8-ec7c-4403-8b57-2477c4a704c3","type":"BasicTickFormatter"},{"attributes":{},"id":"d61b2540-eb22-438c-a37f-9c6a2a381e45","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.069,0.10933434343434345,0.1496686868686869,0.1900030303030303,0.23033737373737 ...

# %% [markdown]
# ## Comparison of Fits

# %% [markdown]
# Examine the error in the shear fit using parameters from the uniaxial fit

# %%
y1 = sf.eval(overlay=uf)
y2 = sf.eval()
err = sqrt(mean((y1-y2)**2)) / average(abs(y2))
print(err)
show(sf.bp_plot(overlay=[bf, uf]))
show(uf.bp_plot(overlay=[sf]))
show(bf.bp_plot(overlay=[uf, sf]))
# Out:
# 0.0831722323787
#     <div class="bk-root">
#         <div class="plotdiv" id="95faaa25-a094-42d6-a4d1-1c712b37578b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("
data",[{"id":"acf9c3a8-e0a2-476c-a911-b52f8f75e201","type":"GlyphRenderer"}]],["Shear Data, fit",[{"id":"51c3a4d2-35de-4faf-ad59-69b9c0ae1069","type":"GlyphRenderer"}]],["Biaxial Data, fit",[{"id":"dc12af1a-28ea-43aa-9bd9-515b6708c65a","type":"GlyphRenderer"}]],["Uniaxial Data, fit",[{"id":"9e10413a-d45e-4224-8c6b-96f6b7176414","type":"GlyphRenderer"}]]],"plot":{"id":"fddfdec4-8e3a-4c11-8153-a09e9e222a73","subtype":"Figure","type":"Plot"}},"id":"79469d37-d8f8-42f9-af21-73c72accbf44","type":"Legend"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.069,0.1034,0.1724,0.2828,0.4276,0.8483,1.3862,2.0,2.4897,3.0345,3.4483,3.7793,4.0621],"y":[58860.0,156960.0,235440.0,329616.0,412020.0,588600.0,765180.0,941760.0,1090872.0,1271376.0,1459728.0,1626498.0,1785420.0]}},"id":"6c3a62ea-bb6e-4c9d-8569-7ba2b374ec71","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"fddfdec4-8e3a-4c11-8153-a09e9e222a73","su ...
#     <div class="bk-root">
#         <div class="plotdiv" id="82de565a-6755-4eda-b39b-96fd89d4a7ae"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#82de565a-6755-4eda-b39b-96fd89d4a7ae").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("82de565a-6755-4eda-b39b-96fd89d4a7ae");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '82de565a-6755-4eda-b39b-96fd89d4a7ae' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3ac99b3d-ba2a-4b08-8536-dc8b0a5aca77":{"roots":{"references":[{"attributes":{"plot":{"id":"95eb07bc-56c4-4ebe-a585-a765f185e608","subtype":"Figure","type":"Plot"}},"id":"60ccf709-2cf1-415d-87a4-0441249e6745","type":"PanTool"},{"attributes":{"below":[{"id":"7aaafa78-454c-4779-a348-46ffeb3e762b","type":"LinearAxis"}],"left":[{"id":"72246702-145a-43c4-ba45-81cd0bd31097","type":"LinearAxis"}],"renderers":[{"id":"7aaafa78-454c-4779-a348-46ffeb3e762b","type":"LinearAxis"},{"id":"535f2da2-45cb-4e57-96a3-fccb679a0389","type":"Grid"},{"id":"72246702-145a-43c4-ba45-81cd0bd31097","type":"LinearAxis"},{"id":"3de4aabb-1172-4a7d-a556-ad07a2f593ea","type":"Grid"},{"id":"f1abb248-2203-4425-9249-09c1544ce915","type":"BoxAnnotation"},{"id":"173d4027-64b8-4daf-9267-9f4c5949ec06","type":"Legend"},{"id":"f121b67b-a66c-4dc1-9ed3-42c4d7facb18","type":"GlyphRenderer"},{"id":"6af47b96-562f-4963-9af1-a17af70ca2a6","type":"GlyphRenderer"},{"id":"7f637148-26a0-4498-a1f5-1b017431046b","type":"GlyphRenderer"}],"title":{"id":"56cf4053-d57d-417d-96e4-2991b331c5ca","type":"Title"},"tool_events":{"id":"7f593838-a5aa-48f1-b87d-c41e67d718a6","type":"ToolEvents"},"toolbar":{"id":"9280433d-63ed-4a53-9db6-6fd095144e66","type":"Toolbar"},"x_range":{"id":"99af2638-ef6c-406b-8836-d98a8d80bf6a","type":"DataRange1d"},"y_range":{"id":"327c7eaa-a96e-4bfe-80da-8b38ceacb97a","type":"DataRange1d"}},"id":"95eb07bc-56c4-4ebe-a585-a765f185e608","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"327c7eaa-a96e-4bfe-80da-8b38ceacb97a","type":"DataRange1d"},{"attributes":{},"id":"7f593838-a5aa-48f1-b87d-c41e67d718a6","type":"ToolEvents"},{"attributes":{"legends":[["Uniaxial Data, data",[{"id":"f121b67b-a66c-4dc1-9ed3-42c4d7facb18","type":"GlyphRenderer"}]],["Uniaxial Data, fit",[{"id":"6af47b96-562f-4963-9af1-a17af70ca2a6","type":"GlyphRenderer"}]],["Shear Data, fit",[{"id":"7f637148-26a0-4498-a1f5-1b017431046b","type":"GlyphRenderer"}]]],"plot":{"id":"95eb07bc-56c4-4ebe-a585-a765f185e608","subtype":"Figure","type":"Plot"}},"id":"173d4027-64b8-4daf-9267-9f4c5949ec06","type":"Legend"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dc5343c5-ab89-426c-a4ae-236bdce6525e","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"95eb07bc-56c4-4ebe-a585-a765f185e608","subtype":"Figure","type":"Plot"},"ticker":{"id":"17995a46-e619-4590-af70-8781d9e7c8b7","type":"BasicTicker"}},"id":"3de4aabb-1172-4a7d-a556-ad07a2f593ea","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a966d2c9-80ec-4326-ab21-34808dc66d37","type":"Line"},{"attributes":{"formatter":{"id":"7f35f1a1-4d81-4c8e-9096-c53158dd3838","type":"BasicTickFormatter"},"plot":{"id":"95eb07bc-56c4-4ebe-a585-a765f185e608","subtype":"Figure","type":"Plot"},"ticker":{"id":"17995a46-e619-4590-af70-8781d9e7c8b7","type":"BasicTicker"}},"id":"72246702-145a-43c4-ba45-81cd0bd31097","type":"LinearAxis"},{"attributes":{"overlay":{"id":"f1abb248-2203-4425-9249-09c1544ce915","type":"BoxAnnotation"},"plot":{"id":"95eb07bc-56c4-4ebe-a585-a765f185e608","subtype":"Figure","type":"Plot"}},"id":"e3d867d7-2556-4759-9fd9-c7397f307eaa","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a1382d70-e3fe-4b94-b1dc-ce6f63c1f9ad","type":"Line"},{"attributes":{},"id":"7f35f1a1-4d81-4c8e-9096-c53158dd3838","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"95eb07bc-56c4-4ebe-a585-a765f185e608","subtype":"Figure","type":"Plot"},"ticker":{"id":"03e50b6f-27ab-4cd7-a8a6-3d97ecc11995","type":"BasicTicker"}},"id":"535f2da2-45cb-4e57-96a3-fccb679a0389","type":"Grid"},{"attributes":{},"id":"03e50b6f-27ab-4cd7-a8a6-3d97ecc11995","type":"BasicTicker"},{"attributes":{"data_source":{"id":"65fbd875-23bb-46ed-b315-fe1b2edc1640 ...
#     <div class="bk-root">
#         <div class="plotdiv" id="36fcaf33-42e0-460b-bbff-cd5ab750d53e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#36fcaf33-42e0-460b-bbff-cd5ab750d53e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("36fcaf33-42e0-460b-bbff-cd5ab750d53e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '36fcaf33-42e0-460b-bbff-cd5ab750d53e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {
type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"2d5ac45b-1d8a-4ed3-8529-eaafddb05d43","type":"Line"},"selection_glyph":null},"id":"07ab59bc-73e4-4c16-aa4a-03df087f79f7","type":"GlyphRenderer"},{"attributes":{},"id":"e579e7a5-391a-44ab-abb3-0d6e49b08e72","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"7740325b-00a7-44be-a861-007037f2fdaf","subtype":"Figure","type":"Plot"},"ticker":{"id":"61777d81-3033-4e21-9e1b-9e162a49b238","type":"BasicTicker"}},"id":"501f1319-38bc-4136-a12d-fc2b1181d109","type":"Grid"},{"attributes":{"overlay":{"id":"8c594dae-6ca6-4233-853c-addbbbf6cfff","type":"BoxAnnotation"},"plot":{"id":"7740325b-00a7-44be-a861-007037f2fdaf","subtype":"Figure","type":"Plot"}},"id":"3f5f3afb-135b-4706-b64f-82609 ...

# %% [markdown]
# ## hyperopt2
#
# `hyperopt2` attempts to find the model that fits all given data the best.

# %%
f = hyperopt2(SHEAR_DATA, sd[:,0], sd[:,1], 
              UNIAXIAL_DATA, ud[:,0], ud[:,1],
              BIAXIAL_DATA, bd[:,0], bd[:,1])

# %%
print(f.summary())
# Out:
#             Data type: Uniaxial
# Number of data points: 23
#      Polynomial order: 4
#         I2 dependence: False
#            Parameters: C10=430761.746, C20=46252.207, C30=-22262.415, C40=3276.462
#                 Error: 0.044158206214665915

# %%
f.error2
# Out:
# 0.017267590200161907

# %%
p = f.bp_plot(strain=linspace(0,6.5), points=False)
p.circle(sd[:,0], sd[:,1], color='black', legend='Shear data')
p.circle(bd[:,0], bd[:,1], color='red', legend='Biaxial data')
p.circle(ud[:,0], ud[:,1], color='green', legend='Uniaxial data')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="726fb726-88ef-4dac-92d5-a9798861491f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#726fb726-88ef-4dac-92d5-a9798861491f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("726fb726-88ef-4dac-92d5-a9798861491f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '726fb726-88ef-4dac-92d5-a9798861491f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"90fa6a87-bd86-437e-83d3-70142eaa1662":{"roots":{"references":[{"attributes":{"formatter":{"id":"0f2ddcb1-6c48-4fb7-b919-2b720a8527c5","type":"BasicTickFormatter"},"plot":{"id":"49320fd5-374d-4e2c-8c17-ff064b6c7631","subtype":"Figure","type":"Plot"},"ticker":{"id":"03ce6ccc-2ec2-443c-8a0f-0a992b3199ad","type":"BasicTicker"}},"id":"8f7d8411-b694-4040-bcbe-5d1bc5a9ea60","type":"LinearAxis"},{"attributes":{"plot":{"id":"49320fd5-374d-4e2c-8c17-ff064b6c7631","subtype":"Figure","type":"Plot"}},"id":"9add3f07-5065-4e51-8802-ff2ff79f6c07","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"49320fd5-374d-4e2c-8c17-ff064b6c7631","subtype":"Figure","type":"Plot"},"ticker":{"id":"fbd03388-df5c-4467-920e-7232dbcf2be6","type":"BasicTicker"}},"id":"544caf6e-52cc-4131-b592-55d439b3d325","type":"Grid"},{"attributes":{},"id":"0f2ddcb1-6c48-4fb7-b919-2b720a8527c5","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":null},"id":"f113492b-5739-4cac-83e8-5c60be82e544","type":"Title"},{"attributes":{"fill_color":{"value":"green"},"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1ffed0c0-f1fb-4759-8836-6fd6aacac7a1","type":"Circle"},{"attributes":{"data_source":{"id":"a1f58e94-5232-4ad5-8130-e4c5ed70a5d8","type":"ColumnDataSource"},"glyph":{"id":"d4869071-c2cd-4dd3-b602-23e50cc6bd9e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":